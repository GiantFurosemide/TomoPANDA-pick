# %%
import sys
import os


# 将当前utils所在目录（tomopanda-pick）加入到sys.path中
notebook_dir = "/Users/muwang/Documents/github/TomoPANDA-pick"
if notebook_dir not in sys.path:
    sys.path.insert(0, notebook_dir)

from utils.io_dynamo import *

# %%
# input
# star file from Pytom
starfile_particle = '/Users/muwang/Documents/github/TomoPANDA-pick/notebooks/production20260112_Pytom_star2tbl/input/merged_particles.star'

# information of tomograms you use in dynamo
pixel_size = 6.72
tomogram_size = (999,999,499)

# tomogram names for dynamo (all tomograms absolute pathes)
vll_path = '/Users/muwang/Documents/github/TomoPANDA-pick/notebooks/production20260112_Pytom_star2tbl/input/all_tomograms_bin8.txt'


# output
output_tbl= '/Users/muwang/Documents/github/TomoPANDA-pick/notebooks/production20260112_Pytom_star2tbl/output/particles_changeTomoName_bin8.tbl'
output_vll = '/Users/muwang/Documents/github/TomoPANDA-pick/notebooks/production20260112_Pytom_star2tbl/output/sorted_tomos_bin8.vll'

# %%
# check pixel size, tomogram size first
# will save to output/particles_changeTomoName_bin8.tbl
df =relion_star_to_dynamo_tbl(
    starfile_particle, 
    pixel_size,
    tomogram_size=tomogram_size, 
    output_file=output_tbl)

# %%
# extract tomogram names from star file
df_star = starfile.read(starfile_particle)
tomo_names = df_star['rlnTomoName'].unique()

# re-orgnize vll file by tomogram names and save to output/sorted_tomos_bin8.vll
vll_path = vll_path
vll_df = read_vll_to_df(vll_path)
save_sorted_vll_by_tomonames(tomo_names, vll_df, output_vll)
# Out:
# Saved vll file sorted by tomo_names to: /Users/muwang/Documents/github/TomoPANDA-pick/notebooks/production20260112_Pytom_star2tbl/output/sorted_tomos_bin8.vll
