# %%
import sys
#import os


# 将当前notebook所在目录（即本文件的上层目录）加入到sys.path中
notebook_dir = "/Users/muwang/Documents/github/TomoPANDA-pick"
if notebook_dir not in sys.path:
    sys.path.insert(0, notebook_dir)

from utils.io_dynamo import *

# %%
# starfile_particle = '/Users/muwang/Documents/github/TomoPANDA-pick/notebooks/input/ryr1_picking_results_20251111/merged_particles.star'
# starfile_particle = '/Users/muwang/Documents/github/TomoPANDA-pick/notebooks/input/5HT3ar_picking_1_20251111/merged_particles.star'
#starfile_particle = '/Users/muwang/Documents/github/TomoPANDA-pick/notebooks/input/5HT3ar_picking_2_20251111/merged_particles.star'

#starfile_particle = '/Users/muwang/Documents/github/TomoPANDA-pick/notebooks/input/5HT3ar_picking_3_20251111/merged_particles.star'
#starfile_particle = '/Users/muwang/Documents/github/TomoPANDA-pick/notebooks/input/5HT3ar_picking_4_20251111/merged_particles.star'


tmp_output_dir = '/Users/muwang/Documents/github/TomoPANDA-pick/notebooks/input/5HT3ar_picking_4_100paticle_20251112'
starfile_particle = f'{tmp_output_dir}/merged_particles.star'

# %%
print(starfile_particle)
# Out:
# /Users/muwang/Documents/github/TomoPANDA-pick/notebooks/input/5HT3ar_picking_4_100paticle_20251112/merged_particles.star

# %%
# !head -n 50 /Users/muwang/Documents/github/TomoPANDA-pick/notebooks/input/5HT3ar_picking_1_100paticle_20251112/merged_particles.star
# Out:
# # Created by the starfile Python package (version 0.5.13) at 10:37:01 on 12/11/2025
#
#
# data_
#
# loop_
# _rlnCenteredCoordinateXAngst #1
# _rlnCenteredCoordinateYAngst #2
# _rlnCenteredCoordinateZAngst #3
# _rlnAngleRot #4
# _rlnAngleTilt #5
# _rlnAnglePsi #6
# _rlnLCCmax #7
# _rlnCutOff #8
# _rlnSearchStd #9
# _rlnTomoTiltSeriesPixelSize #10
# _rlnTomoName #11
# 913.920000	-2513.280000	188.160000	-172.500000	99.594068	112.816901	0.525982	0.323573	0.044239	13.440000	MGS5_001_T1_ts_001
# -833.280000	-2419.200000	309.120000	-11.250000	90.000000	72.253521	0.515000	0.323573	0.044239	13.440000	MGS5_001_T1_ts_001
# -1451.520000	-2822.400000	309.120000	-3.750000	90.000000	46.901408	0.512810	0.323573	0.044239	13.440000	MGS5_001_T1_ts_001
# 1075.200000	-2620.800000	134.400000	-176.250000	102.839588	122.957746	0.509711	0.323573	0.044239	13.440000	MGS5_001_T1_ts_001
# -1720.320000	-3171.840000	188.160000	-3.750000	96.379370	31.690141	0.509650	0.323573	0.044239	13.440000	MGS5_001_T1_ts_001
# ...

# %%
# check pixel size, tomogram size first
# will save to output/particles_changeTomoName_bin8.tbl
df =relion_star_to_dynamo_tbl(
    starfile_particle, 
    #13.6,
    6.72,
    #tomogram_size=(464,480,250), 
    tomogram_size=(999,999,499), 
    output_file=f'{tmp_output_dir}/particles_changeTomoName_bin8.tbl')

# %%
# extract tomogram names from star file
df_star = starfile.read(starfile_particle)
tomo_names = df_star['rlnTomoName'].unique()

# re-orgnize vll file by tomogram names and save to output/sorted_tomos_bin8.vll
# vll_path = f'{tmp_output_dir}/tomograms_all.txt'
vll_path = f'{tmp_output_dir}/all_tomograms_bin8.txt'
vll_df = read_vll_to_df(vll_path)
save_sorted_vll_by_tomonames(tomo_names, vll_df, f"{tmp_output_dir}/sorted_tomos_bin8.vll")
# Out:
# Saved vll file sorted by tomo_names to: /Users/muwang/Documents/github/TomoPANDA-pick/notebooks/input/5HT3ar_picking_4_100paticle_20251112/sorted_tomos_bin8.vll
